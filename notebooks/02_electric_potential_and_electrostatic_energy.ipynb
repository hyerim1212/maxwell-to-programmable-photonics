# %% [markdown]
# # Electric Potential and Electrostatic Energy
#
# ## Electric potential and Potential Difference
#
# When the test charge $q_0$ is in the electric field $\vec{\mathbf{E}}\,$, the test charge is influenced by the electric force, $q_0\vec{\mathbf{E}}\,$. This test charge is written by Coulomb's law, $q_0\vec{\mathbf{E}}\,$ which is a conservative force. In the charge-electric field system, the work that the electric field did on the charge is $$W=\vec{\mathbf{F}}_e \cdot d\vec{s} = q_0\,\vec{\mathbf{E}}\cdot d\vec{s}$$
#
# As electric field work, electric potential energy charge as much $dU = -q_0\vec{\mathbf{E}}\cdot d\vec{s}$.
#
# Therefore,
# $$\Delta U = -q_0\int_{1}^{2}\vec{\mathbf{E}}\cdot d\vec{s}$$
#
# $q_0\vec{\mathbf{E}}\,$ is a conservation force, so $\Delta U$ irrelevant to the route.
#
# When the test charge is located in the electric field, it has a potential $U$ relative to the system at infinity, where $U=0$. When we divide $U$, we obtain a physical quantity that **depends only on the source charge distribution**. We call this physical quantity the electric potential, $V$
# $$V=\frac{U}{q_0} \, [\mathrm{J/C}]$$
#
# So, we can calculate the difference between two locations A, B in the electric field.
# $$\Delta V = \frac{\Delta U}{q_o} = -q_0\int_{A}^{B}\vec{\mathbf{E}}\cdot d\vec{s}$$
#
# When the test charge moves from A to B with constant kinetic energy, then the external force did work to make the point charge's electric potential energy.
# $$W=\Delta U = q\Delta V$$
#
# ## Electric Potential and Potenctial Energy Due to Point Charges
#
# For the electric potential under the electric field created by the point charge, let's use the general equation for potential difference.
#
# $$\Delta V = -q\int_{A}^{B}\vec{\mathbf{E}}\cdot d\vec{s}$$
#
# And we can write the electric field with Coulomb's law
# $$\vec{\mathbf{E}}\cdot d\vec{{s}} = k_e\frac{q}{r^2}\hat{\mathbf{r}}\cdot d{\vec{{s}}}$$
# $\left| \hat{\mathbf{r}} \right| = 1$,
# $$\hat{\mathbf{r}} \cdot d\vec{s} = ds \cos\theta $$ $$ds \cos\theta = dr $$
#
# If we substitute this into the above equation,
#
# $$\Delta V = -k_e q\int_{r_A}^{r_B}\frac{dr}{r^2}$$
# $$\Delta V = -k_e q[\frac{1}{r_B}-\frac{1}{r_B}]$$
#
# Let's set the $V_{r = \infty}$ to reference point, $r_\infty = \infty$
# $$V - V_{r = \infty} = -k_e q[\frac{1}{r}-\frac{1}{r_\infty}] $$
# Therefore, we can get a general equation about electric potential $V$,
# $$V = -k_e q\frac{1}{r} $$
#
# Furthermore,
#
# Because of Principle of superposition,
#
# $$V = k_e \sum_{i}\frac{q_i}{r_i}$$
#
# ## Obtaining the Value of the Electric Field from the Electric Potential
# From $\Delta V = -q\int_{A}^{B}\vec{\mathbf{E}}\cdot d\vec{s}$,
#
# we can get $$dV = -\vec{\mathbf{E}}\cdot d\vec{{s}}$$
# Let's describe $dV$ with vector form
# $$ dV = [\frac{\partial V}{\partial x}dx +\frac{\partial V}{\partial y}dy + \frac{\partial V}{\partial z}dz] $$
# Let's describe $\vec{\mathbf{E}}$ with vector form
# $$ \vec{\mathbf{E}}\cdot d\vec{{s}} = \vec{\mathbf{E}}_x dx + \vec{\mathbf{E}}_y dy + \vec{\mathbf{E}}_z dz$$
# If we organize this,
# $$\vec{\mathbf{E}}_x = - \frac{\partial V}{\partial x} \quad \vec{\mathbf{E}}_y = - \frac{\partial V}{\partial y}\quad \vec{\mathbf{E}}_z = - \frac{\partial V}{\partial z}$$
#
# $$\vec{\mathbf{E}} = -(\frac{\partial V}{\partial x}\hat{i}+\frac{\partial V}{\partial y}\hat{j}+\frac{\partial V}{\partial x}\hat{k})$$
#
# $$\vec{\mathbf{E}} = -\nabla V$$
#
# ## Electric Potential Due to Continuous Charge Distributions
#
# We can calculate the electric potential of a continuous charge distribution.
# If we know the distribution of continuous charge, We can write the equation with reference point $P$
# $$dV = k_e \frac{dq}{r}$$
# $$V = k_e \int\frac{dq}{r}$$
#
# and also we can use Gauss's law.
#
# It determines whether the electric potential is constant at every point on the surface of a charged conductor.

# %%
from src.electric_potential import electric_potential_point_charge, electric_potential_multiple_charges, electrostatic_potential_energy

# %% [markdown]
# ---
# ## Case 1: Electric Potential and Electrostatic Energy of Two Point Charges
#
# Two point charges are placed on the (x)-axis:
#
# $$q_1=+1.0\times10^{-9}\ \mathrm{C} \qquad q_2=-1.0\times10^{-9}\ \mathrm{C}$$
#
# at the positions
#
#
# $$\mathbf r_1=(-0.05,0)\ \mathrm{m} \qquad \mathbf r_2=(0.05,0)\ \mathrm{m}.$$
#
#
#
#
# ### Questions
#
# 1. What is the electric potential at the origin?
#
# 2. Is the electric field at the origin equal to zero? Explain why the electric potential and electric field behave differently at this point.
#
# 3. What is the value of the potential along the (y)-axis? Explain the result using the symmetry of the charge configuration.
#
# 4. Are the electric-field vectors perpendicular to the equipotential lines?
#
# 5. In which direction does the electric field point relative to increasing and decreasing electric potential?
#
# 6. Why does the numerical electric field obtained from (-\nabla V) become inaccurate near the point charges?
#
# 7. Why should the charge positions and the outer boundaries of the computational domain be excluded when evaluating the numerical error?
#
# 8. Is the electrostatic potential energy of the system positive or negative? What does its sign indicate physically?
#
#
# ### Physical Interpretation
#
# Use the numerical results to explain why electric potential is a scalar quantity while the electric field is a vector quantity. In particular, discuss how a point can have zero electric potential even when the electric field at that point is not zero.

# %% [markdown]
# ## Results
# ## Physical interpretations with answering the questions.

# %% [markdown]
# ---
# ## Case 2. Electric Dipole
#
# A positive point charge and a negative point charge of equal magnitude are placed symmetrically on the $x$-axis.
#
# $$q_1=+q \qquad q_2=-q$$
#
# Their positions are
#
# $$\mathbf r_1=(-a,0)\qquad \mathbf r_2=(a,0)$$
#
# Use the following numerical values:
#
# $$q=1.0\times10^{-9} \mathrm{C},\qquad a=0.05 \mathrm{m}$$
#
# Assume that the charges are located in vacuum.
#
#
# ### Task 1. Construct the computational domain
#
# Create a two-dimensional grid over the region
#
# $$-0.20\le x\le0.20\ \mathrm{m} \qquad -0.20\le y\le0.20\ \mathrm{m}$$
# ]
#
# Use a sufficiently dense grid so that the spatial variation of the potential can be observed clearly.
#
# Exclude the exact positions of the point charges because the electric potential is undefined there.
#
# ### Task 2. Calculate the electric potential
#
# Using the electric-potential functions implemented previously, calculate the total electric potential at every point on the grid.
#
# Store the results in a two-dimensional array with the same shape as the coordinate grid.
#
# ### Task 3. Plot the equipotential lines
#
# Create a contour plot of the electric potential.
#
# The plot must include:
#
# * equipotential lines,
# * the position of the positive charge,
# * the position of the negative charge,
# * labels or a legend identifying the charges,
# * equal scaling of the $x$- and $y$-axes.
#
# Choose the contour levels so that both positive and negative potential regions are visible.
#
# ### Task 4. Investigate the perpendicular bisector
#
# Evaluate the electric potential along the $y$-axis, where
#
# $$x=0$$
#
#
# Determine whether
#
# $$V(0,y)=0$$
#
# for all values of (y) except at singular points.
#
# Explain the result using the symmetry of the charge configuration.
#
# ### Task 5. Compare potential and electric field at the origin
#
# Calculate the electric potential at the origin:
#
# $$V(0,0)$$
#
# Then calculate the electric field at the origin using the previously implemented electric-field function:
#
# $$\mathbf E(0,0)$$
#
# Answer the following questions.
#
# 1. Is the electric potential at the origin zero?
# 2. Is the electric field at the origin zero?
# 3. In which direction does the electric field point?
# 4. Why can the electric potential be zero while the electric field is nonzero?
#
# ### Task 6. Overlay the electric field
#
# Calculate the electric field over the same computational grid and visualize it together with the equipotential lines.
#
# Use either a `quiver` plot or a `streamplot`.
#
# To avoid excessively large vectors near the point charges, normalize the electric-field vectors or mask the region close to each charge.
#
# Check whether the electric-field lines are perpendicular to the equipotential lines.
#
# ### Task 7. Verify the relation between potential and field
#
# Use the numerically calculated potential to estimate the electric field:
#
# $$E_x=-\frac{\partial V}{\partial x} \qquad E_y=-\frac{\partial V}{\partial y}$$
#
#
# Use a numerical gradient method such as `numpy.gradient`.
#
# Compare the numerically reconstructed field,
#
# $$\mathbf E_{\mathrm{potential}}=-\nabla V$$
#
# with the field calculated directly from Coulomb’s law,
#
# $$\mathbf E_{\mathrm{direct}}$$
#
# Calculate the absolute error:
#
# $$\Delta E$$
#
#
# Exclude the following regions from the error analysis:
#
# * points close to the source charges,
# * the outer boundary of the grid,
# * points where the direct electric-field magnitude is extremely small.
#
# ### Questions for Physical Interpretation
#
# 1. Why is the entire $y$-axis an equipotential line with $V=0$?
#
# 2. Does $V=0$ imply that no electric effect exists at that point?
#
# 3. Why does the electric field at the origin point from the positive charge toward the negative charge?
#
# 4. Why are the equipotential lines symmetric with respect to the $x$-axis?
#
# 5. Why are the positive and negative potential regions antisymmetric with respect to the $y$-axis?
#
# 6. Why does the numerical approximation of $-\nabla V$ become inaccurate near the point charges?
#
# 7. How does increasing the number of grid points affect the agreement between the direct electric field and the field obtained from the potential?
#
#
# ### Final Objective
#
# Use this case to demonstrate that electric potential and electric field describe the same electrostatic system in different ways:
#
# * electric potential is a scalar quantity,
# * electric field is a vector quantity,
# * zero potential does not necessarily imply zero electric field,
# * the electric field points in the direction of decreasing electric potential.

# %% [markdown]
# ## Results
# ## Physical interpretations with answering the questions.

# %% [markdown]
# ---
# ## Case 3. Two Equal Positive Charges
#
# Two identical positive point charges are placed symmetrically on the (x)-axis:
#
# $$q_1=q_2=1.0\times10^{-9}\ \mathrm{C}$$
#
# $$\mathbf r_1=(-0.05,0)\ \mathrm{m} \qquad \mathbf r_2=(0.05,0)\ \mathrm{m}$$
#
# ### Task
#
# 1. Calculate the electric potential at the origin.
#
# 2. Calculate the net electric field at the origin.
#
# 3. Explain why the electric field is zero while the electric potential is not zero.

# %% [markdown]
# ## Results
# ## Physical interpretations with answering the questions.

# %% [markdown]
# ## Case 4. Reconstructing the Electric Field from the Potential
#
# A single positive point charge is located at the origin:
#
# $$q=1.0\times10^{-9}\ \mathrm{C}$$
#
# Construct a two-dimensional grid over
#
# $$-0.20\le x\le0.20\ \mathrm{m} \qquad -0.20\le y\le0.20\ \mathrm{m}$$
#
#
# Calculate the electric potential on the grid using
#
# $$V(\mathbf r)$$
#
# Then reconstruct the electric field numerically from the potential:
#
# $$E_x=-\frac{\partial V}{\partial x} \qquad E_y=-\frac{\partial V}{\partial y}$$
#
# Use `numpy.gradient` to approximate the spatial derivatives.
#
# ### Tasks
#
# 1. Calculate the potential $V$ at every grid point.
#
# 2. Obtain $E_x$ and $E_y$ from the numerical gradient of $V$
#
# 3. Calculate the electric field directly from Coulomb’s law.
#
# 4. Compare the two results using the absolute error $\Delta E$
#
# 5. Visualize either the reconstructed electric field or the error distribution.
#
# Exclude the charge position and nearby grid points from the comparison because both the potential and the electric field become singular there.
#
# ### Questions
#
# 1. Does the reconstructed electric field point radially outward from the positive charge?
#
# 2. In which regions do the direct and reconstructed fields agree well?
#
# 3. Why is the numerical error large near the charge and near the boundaries of the grid?
#
# 4. How does increasing the grid resolution affect the error?
#
# ### Expected Result
#
# Away from the charge and the outer boundary,
#
# $$\mathbf E_{\mathrm{gradient}}\approx \mathbf E_{\mathrm{direct}}$$
#
# The electric field should point in the direction of decreasing electric potential.

# %% [markdown]
# ## Results
# ## Physical interpretations with answering the questions.

# %% [markdown]
# ---
# ## Case 5. Electrostatic Potential Energy
#
# Two point charges are placed (0.10\ \mathrm{m}) apart:
#
# $$q_1=1.0\times10^{-9}\ \mathrm{C} \qquad q_2=-1.0\times10^{-9}\ \mathrm{C}$$
#
# The electrostatic potential energy is
#
# $$U=K_e\frac{q_1q_2}{r}$$
#
# ### Tasks
#
# 1. Calculate the electrostatic potential energy of the system.
#
# 2. Repeat the calculation when $q_2$ is replaced by $+1.0\times10^{-9} \mathrm{C}$
#
# 3. Explain what the sign of $U$ indicates about the interaction between the charges.
#
# 4. Check how $U$ changes when the separation distance is doubled.

# %% [markdown]
# ## Results
# ## Physical interpretations with answering the questions.
